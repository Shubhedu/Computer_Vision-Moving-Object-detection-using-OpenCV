# %%
import cv2
import time
import imutils

# Initialize the camera
cam = cv2.VideoCapture(0)
time.sleep(1)
firstFrame = None
i = 0
area = 500

while True:
    _,img = cam.read()
    text = "Normal"
    
    # Resize Image
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Generating Gaussian image
    gaussianImg = cv2.GaussianBlur(grayImg, (21, 21), 0)
    if firstFrame is None:
        firstFrame = gaussianImg
        continue
    imgDiff = cv2.absdiff(firstFrame, gaussianImg)
    threshImg = cv2.threshold(imgDiff, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)
    
    # Finding Edges of the image
    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL,
            cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    for c in cnts:
            if cv2.contourArea(c) < area:
                    continue
            (x, y, w, h) = cv2.boundingRect(c)
            cv2.rectangle(img, (x, y), (x + w, y + h),(0, 255, 0), 2)
            i += 1
            # Count the no. of moving objcts
            text = ("Moving Object detected: " + str(i))

    print(text)
    cv2.putText(img, text, (10, 20),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
    
    # Showing Camera Feed
    cv2.imshow("CameraFeed", img)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# Normal
# Normal
# Normal
# Normal
# Normal
# Moving Object detected: 2
# Moving Object detected: 4
# Moving Object detected: 6
# Moving Object detected: 8
# Moving Object detected: 10
# Moving Object detected: 12
# Moving Object detected: 14
# Moving Object detected: 16
# Moving Object detected: 17
# Moving Object detected: 18
# Moving Object detected: 19
# Moving Object detected: 20
# Moving Object detected: 21
# Moving Object detected: 22
# Moving Object detected: 23
# Moving Object detected: 24
# Moving Object detected: 26
# Moving Object detected: 28
# Moving Object detected: 30
# Moving Object detected: 32
# Moving Object detected: 34
# Moving Object detected: 36
# Moving Object detected: 38
# Moving Object detected: 40
# Moving Object detected: 42
# Moving Object detected: 43
# Moving Object detected: 44
# Moving Object detected: 45
# Moving Object detected: 46
# Moving Object detected: 47
# Moving Object detected: 48
# Moving Object detected: 49
# Moving Object detected: 50
# Moving Object detected: 51
# Moving Object detected: 52
# Moving Object detected: 53
# Moving Object detected: 54
# Moving Object detected: 55
# Moving Object detected: 56
# Moving Object detected: 57
# Moving Object detected: 58
# Moving Object detected: 59
# Moving Object detected: 60
# Moving Object detected: 61
# Moving Object detected: 62
# Moving Object detected: 63
# Moving Object detected: 64
# Moving Object detected: 65
# Moving Object detected: 66
# Moving Object detected: 67
# Moving Object detected: 68
# Moving Object detected: 69
# Moving Object detected: 70
# Moving Object detected: 71
# Moving Object detected: 72
# Moving Object detected: 73
# Moving Object detected: 74
# Moving Object detected: 75
# Moving Object detected: 76
# Moving Object detected: 77
# Moving Object detected: 78
# Moving Object detected: 79
# Moving Object detected: 80
# Moving Object detected: 81
# Moving Object detected: 82
# Moving Object detected: 83
# Moving Object detected: 84
# Moving Object detected: 85
# Moving Object detected: 86
# Moving Object detected: 87
# Moving Object detected: 88
# Moving Object detected: 89
# Moving Object detected: 90
# Moving Object detected: 91
# Moving Object detected: 92
# Moving Object detected: 93
# Moving Object detected: 94
# Moving Object detected: 95
# Moving Object detected: 96
# Moving Object detected: 97
# Moving Object detected: 98
# Moving Object detected: 99
# Moving Object detected: 100
# Moving Object detected: 101
# Moving Object detected: 102
# Moving Object detected: 103
# Moving Object detected: 104
# Moving Object detected: 105
# Moving Object detected: 106
# Moving Object detected: 107
# Moving Object detected: 108
# Moving Object detected: 109
# Moving Object detected: 110
# Moving Object detected: 111
# Moving Object detected: 112
# Moving Object detected: 113
# Moving Object detected: 114
# Moving Object detected: 115
# Moving Object detected: 116
# Moving Object detected: 117
# Moving Object detected: 118
# Moving Object detected: 119
# Moving Object detected: 120
# Moving Object detected: 121
# Moving Object detected: 122
# Moving Object detected: 123
# Moving Object detected: 124
# Moving Object detected: 125
# Moving Object detected: 126
# Moving Object detected: 127
# Moving Object detected: 128
# Moving Object detected: 129
# Moving Object detected: 130
# Moving Object detected: 131
# Moving Object detected: 132
# Moving Object detected: 133
# Moving Object detected: 134
# Moving Object detected: 135
# Moving Object detected: 136
# Moving Object detected: 137
# Moving Object detected: 138
# Moving Object detected: 139
# Moving Object detected: 140
# Moving Object detected: 141
# Moving Object detected: 142
# Moving Object detected: 143
# Moving Object detected: 144
# Moving Object detected: 145
# Moving Object detected: 146
# Moving Object detected: 147
# Moving Object detected: 148
# Moving Object detected: 149
# Moving Object detected: 150
# Moving Object detected: 151
# Moving Object detected: 152
# Moving Object detected: 153
# Moving Object detected: 154
# Moving Object detected: 155
# Moving Object detected: 156
# Moving Object detected: 157
# Moving Object detected: 158
# Moving Object detected: 159
# Moving Object detected: 160
# Moving Object detected: 161
# Moving Object detected: 162
# Moving Object detected: 163
# Moving Object detected: 164
# Moving Object detected: 165
# Moving Object detected: 166
# Moving Object detected: 167
# Moving Object detected: 168
# Moving Object detected: 169
# Moving Object detected: 170
# Moving Object detected: 171
# Moving Object detected: 172
# Moving Object detected: 173
# Moving Object detected: 174
# Moving Object detected: 175
# Moving Object detected: 176
# Moving Object detected: 177
# Moving Object detected: 178
